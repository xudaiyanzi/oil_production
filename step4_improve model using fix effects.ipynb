# %%
############################################################################################################################
#############################                     convert data into df                    ##################################
############################################################################################################################


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from patsy import dmatrices
import statsmodels.api as sm


from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant


# read data as framework
df = pd.read_csv('./data_integer_shift_column.csv')

# check the framework

#df.head()

# %%
############################## according to step 2 the following attributes are important for regression

                                #'tvd (ft)',
                                # 'well spacing',
                                # 'log permeability',
                                # 'porosity',
                                # 'poisson ratio',
                                # 'p-velocity',
                                # 's-velocity', 
                                # 'youngs modulus', 
                                # 'total number of stages',
                                # 'proppant volume',
                                # 'date_sec',
                                # 'op_number',
                                # 'production'

############################## according to step 3 adj R2 was too small ~0.55


############################## thus, the model need to be improved

# %%
############################################################################################################################
###################          use fix effect to improve the model and increase adj R2           ##########################################
######################################################################################################################



##################### record the attributes and use the orginal data in the attributes to repeat the adj R 2

df_att = df[['tvd (ft)',
             'well spacing',
             'log permeability',
             'porosity',
             'poisson ratio',
             'p-velocity',
             's-velocity', 
             'youngs modulus', 
             'total number of stages',
             'proppant volume',
             'date_sec',
              'op_number',
             'production']]
df_att_drop = df_att.dropna()


##################### set x and y for the models
x = df_att_drop.drop(['production'], axis=1)
y = df_att_drop['production']

# %%
###############################  use critical varables to predict, find adj R2 BEFORE 'fixed effect' function
X2 = sm.add_constant(x)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             production   R-squared:                       0.561
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                     64.75
# Date:                Tue, 27 Oct 2020   Prob (F-statistic):          2.60e-100
# Time:                        16:33:25   Log-Likelihood:                -5142.6
# No. Observations:                 621   AIC:                         1.031e+04
# Df Residuals:                     608   BIC:                         1.037e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                   7975.4201   2145.390      3.717      0.000    3762.146    1.22e+04
# tvd (ft)                   0.4190      0.054      7.806      0.000       0.314       0.524
# well spacing               0.0718      0.031      2.325      0.020       0.011       0.132
# log permeability        -330.0246    145.716     -2.265      0.024    -616.193     -43.856
# porosity               -5961.5641   2318.355     -2.571      0.010   -1.05e+04   -1408.608
# poisson ratio           6160.6024   2229.723      2.763      0.006    1781.708    1.05e+04
# p-velocity                -0.5751      0.086     -6.650      0.000      -0.745      -0.405
# s-velocity                 1.1200      0.430      2.608      0.009       0.277       1.964
# youngs modulus          -476.8159     74.732     -6.380      0.000    -623.580    -330.052
# total number of stages    19.3823      4.415      4.390      0.000      10.712      28.053
# proppant volume         9.343e-05   1.06e-05      8.791      0.000    7.26e-05       0.000
# date_sec                1.376e-06   7.55e-07      1.821      0.069   -1.08e-07    2.86e-06
# op_number                 -6.9097      5.325     -1.298      0.195     -17.367       3.548
# ==============================================================================
# Omnibus:                      185.505   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              753.455
# Skew:                           1.320   Prob(JB):                    2.45e-164
# Kurtosis:                       7.706   Cond. No.                     9.56e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.56e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/yanxu/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
#### The adj R2 before improvement was 0.552

# %%
###############################  use critical varables to predict, find adj R2 before 'fixed effect' function

df_FE = sm.OLS(endog=y, exog=x, entity_effects=True).fit()
print(df_FE.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             production   R-squared (uncentered):                   0.848
# Model:                            OLS   Adj. R-squared (uncentered):              0.845
# Method:                 Least Squares   F-statistic:                              282.1
# Date:                Tue, 27 Oct 2020   Prob (F-statistic):                   1.97e-239
# Time:                        16:33:25   Log-Likelihood:                         -5149.6
# No. Observations:                 621   AIC:                                  1.032e+04
# Df Residuals:                     609   BIC:                                  1.038e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# tvd (ft)                   0.4670      0.053      8.869      0.000       0.364       0.570
# well spacing               0.0741      0.031      2.376      0.018       0.013       0.135
# log permeability        -276.6345    146.525     -1.888      0.060    -564.390      11.121
# porosity               -4938.9802   2326.081     -2.123      0.034   -9507.094    -370.867
# poisson ratio           8281.0031   2178.102      3.802      0.000    4003.500    1.26e+04
# p-velocity                -0.5143      0.086     -5.994      0.000      -0.683      -0.346
# s-velocity                 2.1272      0.337      6.316      0.000       1.466       2.789
# youngs modulus          -568.0755     71.324     -7.965      0.000    -708.146    -428.005
# total number of stages    16.8663      4.409      3.826      0.000       8.208      25.524
# proppant volume         8.928e-05   1.07e-05      8.359      0.000    6.83e-05       0.000
# date_sec                2.802e-06   6.58e-07      4.262      0.000    1.51e-06    4.09e-06
# op_number                 -7.7977      5.375     -1.451      0.147     -18.354       2.758
# ==============================================================================
# Omnibus:                      193.130   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              778.043
# Skew:                           1.383   Prob(JB):                    1.12e-169
# Kurtosis:                       7.735   Cond. No.                     8.77e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.77e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Another syntex for Fix effects


# FE_ols = sm.OLS(endog=y, exog=x, formula='logrealwage ~ HHI+C(Cz)+C(yQ)-1',
#                               data=df_att_drop).fit()
# print(FE_ols.summary())

# %%
#########################################     find the attribute with too large P value (P >0.1)

### according to reference, if |P value| < 0.05, the feature is significant
### to be conservative, we choose |P value| < 0.1, and delete the value =>0.1


### so we need to delete 'operator'

# %%
#########################################     delete 'operator'

df_att_drop_2 = df_att_drop.drop(['op_number'], axis=1)

# %%
##################### set x and y for the models
x = df_att_drop_2.drop(['production'], axis=1)
y = df_att_drop_2['production']

# %%
###############################  use critical varables to predict, find adj R2 before 'fixed effect' function

df_FE = sm.OLS(endog=y, exog=x, entity_effects=True).fit()
print(df_FE.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             production   R-squared (uncentered):                   0.847
# Model:                            OLS   Adj. R-squared (uncentered):              0.844
# Method:                 Least Squares   F-statistic:                              307.0
# Date:                Tue, 27 Oct 2020   Prob (F-statistic):                   3.13e-240
# Time:                        16:33:25   Log-Likelihood:                         -5150.7
# No. Observations:                 621   AIC:                                  1.032e+04
# Df Residuals:                     610   BIC:                                  1.037e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# tvd (ft)                   0.4592      0.052      8.759      0.000       0.356       0.562
# well spacing               0.0758      0.031      2.428      0.015       0.014       0.137
# log permeability        -300.4283    145.736     -2.061      0.040    -586.633     -14.223
# porosity               -4302.5718   2286.406     -1.882      0.060   -8792.755     187.611
# poisson ratio           8105.0813   2176.692      3.724      0.000    3830.362    1.24e+04
# p-velocity                -0.4963      0.085     -5.841      0.000      -0.663      -0.329
# s-velocity                 2.0642      0.334      6.175      0.000       1.408       2.721
# youngs modulus          -566.1183     71.376     -7.932      0.000    -706.290    -425.947
# total number of stages    17.3564      4.400      3.945      0.000       8.716      25.997
# proppant volume         8.879e-05   1.07e-05      8.310      0.000    6.78e-05       0.000
# date_sec                2.911e-06   6.54e-07      4.453      0.000    1.63e-06     4.2e-06
# ==============================================================================
# Omnibus:                      188.656   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              749.745
# Skew:                           1.353   Prob(JB):                    1.57e-163
# Kurtosis:                       7.653   Cond. No.                     8.69e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.69e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#### after deleting 'op_number', i.e., 'operator', the changes in R2 was negligible
#### this indicates that our deletion was reasonable -  does not hurt the model

# %%
############################################################################################################################
###############################                     find coefficient            ############################################
############################################################################################################################


###############################          covert summary table into DataFrame  
rslt_sum = df_FE.summary().tables[1]
df_rslt_sum = pd.DataFrame(rslt_sum)
df_rslt_sum
# Out:
#                          0           1          2          3       4  \
# 0                                 coef    std err          t   P>|t|
# 1                 tvd (ft)      0.4592      0.052      8.759   0.000
# 2             well spacing      0.0758      0.031      2.428   0.015
# 3         log permeability   -300.4283    145.736     -2.061   0.040
# 4                 porosity  -4302.5718   2286.406     -1.882   0.060
# 5            poisson ratio   8105.0813   2176.692      3.724   0.000
# 6               p-velocity     -0.4963      0.085     -5.841   0.000
# 7               s-velocity      2.0642      0.334      6.175   0.000
# 8           youngs modulus   -566.1183     71.376     -7.932   0.000
# 9   total number of stages     17.3564      4.400      3.945   0.000
# 10         proppant volume   8.879e-05   1.07e-05      8.310   0.000
# 11                date_sec   2.911e-06   6.54e-07      4.453   0.000
#
#             5          6
# 0      [0.025     0.975]
# 1       0.356      0.562
# 2       0.014      0.137
# 3    -586.633    -14.223
# 4   -8792.755    187.611
# 5    3830.362   1.24e+04
# 6      -0.663     -0.329
# 7       1.408      2.721
# 8    -706.290   -425.947
# 9       8.716     25.997
# 10   6.78e-05      0.000
# 11   1.63e-06    4.2e-06

# %%
###############################          use the first raw as the columns name  

#grab the first row for the header
new_header = df_rslt_sum.iloc[0] 

#take the data less the header row
df_rslt_sum = df_rslt_sum[1:] 

#set the header row as the df header
df_rslt_sum.columns = new_header

df_rslt_sum
# Out:
# 0                                 coef    std err          t   P>|t|  \
# 1                 tvd (ft)      0.4592      0.052      8.759   0.000
# 2             well spacing      0.0758      0.031      2.428   0.015
# 3         log permeability   -300.4283    145.736     -2.061   0.040
# 4                 porosity  -4302.5718   2286.406     -1.882   0.060
# 5            poisson ratio   8105.0813   2176.692      3.724   0.000
# 6               p-velocity     -0.4963      0.085     -5.841   0.000
# 7               s-velocity      2.0642      0.334      6.175   0.000
# 8           youngs modulus   -566.1183     71.376     -7.932   0.000
# 9   total number of stages     17.3564      4.400      3.945   0.000
# 10         proppant volume   8.879e-05   1.07e-05      8.310   0.000
# 11                date_sec   2.911e-06   6.54e-07      4.453   0.000
#
# 0      [0.025     0.975]
# 1       0.356      0.562
# 2       0.014      0.137
# 3    -586.633    -14.223
# 4   -8792.755    187.611
# 5    3830.362   1.24e+04
# 6      -0.663     -0.329
# 7       1.408      2.721
# 8    -706.290   -425.947
# 9       8.716     25.997
# 10   6.78e-05      0.000
# 11   1.63e-06    4.2e-06

# %%
###############################          use the first column as the index

#rename the first column
df_rslt_sum_new = df_rslt_sum.rename(columns={ df_rslt_sum.columns[0]: 'features' })

df_rslt_sum_new
# Out:
# 0                 features        coef    std err          t   P>|t|  \
# 1                 tvd (ft)      0.4592      0.052      8.759   0.000
# 2             well spacing      0.0758      0.031      2.428   0.015
# 3         log permeability   -300.4283    145.736     -2.061   0.040
# 4                 porosity  -4302.5718   2286.406     -1.882   0.060
# 5            poisson ratio   8105.0813   2176.692      3.724   0.000
# 6               p-velocity     -0.4963      0.085     -5.841   0.000
# 7               s-velocity      2.0642      0.334      6.175   0.000
# 8           youngs modulus   -566.1183     71.376     -7.932   0.000
# 9   total number of stages     17.3564      4.400      3.945   0.000
# 10         proppant volume   8.879e-05   1.07e-05      8.310   0.000
# 11                date_sec   2.911e-06   6.54e-07      4.453   0.000
#
# 0      [0.025     0.975]
# 1       0.356      0.562
# 2       0.014      0.137
# 3    -586.633    -14.223
# 4   -8792.755    187.611
# 5    3830.362   1.24e+04
# 6      -0.663     -0.329
# 7       1.408      2.721
# 8    -706.290   -425.947
# 9       8.716     25.997
# 10   6.78e-05      0.000
# 11   1.63e-06    4.2e-06

# %%
# list the data type
list(df_rslt_sum_new.columns)
# Out:
# ['features',
#  <statsmodels.iolib.table.Cell at 0x7fe48bcb7dd8>,
#  <statsmodels.iolib.table.Cell at 0x7fe48bcc57f0>,
#  <statsmodels.iolib.table.Cell at 0x7fe48bcc57b8>,
#  <statsmodels.iolib.table.Cell at 0x7fe48bcc5780>,
#  <statsmodels.iolib.table.Cell at 0x7fe48bcc5828>,
#  <statsmodels.iolib.table.Cell at 0x7fe48bcc5860>]

# %%
# convert DataFrame as CSV file and then convert back to change the 'statsmodels.iolib.table.Cell' format

df_rslt_sum_new.to_csv('df_transition.csv',index=False)

# read data as framework
df_transition = pd.read_csv('./df_transition.csv')

# %%
############################################################################################################################
###############################                     result            ############################################
############################################################################################################################

## R2 was 0.847
## adj R2 was 0.844

# read data as framework
df_transition[['features','coef','P>|t|']]
# Out:
#                   features         coef  P>|t|
# 0                 tvd (ft)     0.459200  0.000
# 1             well spacing     0.075800  0.015
# 2         log permeability  -300.428300  0.040
# 3                 porosity -4302.571800  0.060
# 4            poisson ratio  8105.081300  0.000
# 5               p-velocity    -0.496300  0.000
# 6               s-velocity     2.064200  0.000
# 7           youngs modulus  -566.118300  0.000
# 8   total number of stages    17.356400  0.000
# 9          proppant volume     0.000089  0.000
# 10                date_sec     0.000003  0.000
